# %% [markdown]
# #**Data Visualization**

# %% [markdown]
# installing libraries and packages:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# uploading dataset file:

# %%
df = pd.read_csv('/content/latestdata.csv')
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1,2,9,10,12,13,14,15,16,17,19,20,21,22,23,24,25,26,27,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                   ID   age     sex            city          province  \
# 0            000-1-1   NaN    male        Shek Lei         Hong Kong
# 1           000-1-10    78    male      Vo Euganeo            Veneto
# 2          000-1-100    61  female             NaN               NaN
# 3         000-1-1000   NaN     NaN  Zhengzhou City             Henan
# 4        000-1-10000   NaN     NaN  Pingxiang City           Jiangxi
# ...              ...   ...     ...             ...               ...
# 2676306    010-99995  52.0  female        Calleria  Coronel Portillo
# 2676307    010-99996  52.0  female    Pueblo Libre              Lima
# 2676308    010-99997  52.0  female           Comas              Lima
# 2676309    010-99998  52.0    male          Callao            Callao
# 2676310    010-99999  52.0    male      Los Olivos              Lima
#
#            country   latitude   longitude geo_resolution date_onset_symptoms  \
# 0            China  22.365019  114.133808          point                 NaN
# 1            Italy  45.297748   11.658382          point                 NaN
# 2        Singapore   1.353460  103.815100         admin0                 NaN
# 3            China  34.629310  113.468000         admin2                 NaN
# 4            China  27.513560  113.902900         admin2                 NaN
# ...            ...        ...         ...            ...                 ...
# 2676306       Peru  -8.378190  -74.539700          point                 NaN
# 2676307       Peru -12.076530  -77.067350          point                 NaN
# 2676308       Peru -11.932980  -77.040850          point                 NaN
# 2676309       Peru -12.000740  -77.118240          point                 NaN
# 2676310       Peru -11.976260  -77.075030          point                 NaN
#
#          ... date_death_or_discharge notes_for_discussion     location admin3  \
# 0        ...                     NaN                  NaN     Shek Lei    NaN
# 1        ...              22.02.2020                  NaN  Vo' Euganeo    NaN
# 2        ...              17.02.2020                  NaN          NaN    NaN
# 3        ...                     NaN                  NaN          NaN    NaN
# 4        ...                     NaN                  NaN          NaN    NaN
# ...      ...                     ...                  ...          ...    ...
# 2676306  ...                     NaN                  NaN          NaN    NaN
# 2676307  ...                     NaN                  NaN          NaN    NaN
# 2676308  ...                     NaN                  NaN          NaN    NaN
# 2676309  ...                     NaN                  NaN          NaN    NaN
# 2676310  ...                     NaN                  NaN          NaN    NaN
#
#                  admin2     admin1 country_new admin_id  \
# 0                   NaN  Hong Kong       China   8029.0
# 1                   NaN     Veneto       Italy   8954.0
# 2                   NaN        NaN   Singapore    200.0
# 3        Zhengzhou City      Henan       China  10091.0
# 4        Pingxiang City    Jiangxi       China   7060.0
# ...                 ...        ...         ...      ...
# 2676306             NaN        NaN        Peru  14429.0
# 2676307             NaN        NaN        Peru  14695.0
# 2676308             NaN        NaN        Peru  14400.0
# 2676309             NaN        NaN        Peru  14516.0
# 2676310             NaN        NaN        Peru  14502.0
#
#          data_moderator_initials travel_history_binary
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# ...                          ...                   ...
# 2676306                      NaN                 False
# 2676307                      NaN                 False
# 2676308                      NaN                 False
# 2676309                      NaN                 False
# 2676310                      NaN                 False
#
# [2676311 rows x 33 columns]

# %% [markdown]
# all NaN values in each columns:

# %%
df.isnull().sum()
# Out:
# ID                                0
# age                         2098293
# sex                         2096154
# city                         977681
# province                     452664
# country                         115
# latitude                         70
# longitude                        70
# geo_resolution                   70
# date_onset_symptoms         2414712
# date_admission_hospital     2560100
# date_confirmation            108489
# symptoms                    2674259
# lives_in_Wuhan              2671973
# travel_history_dates        2673700
# travel_history_location     2667089
# reported_market_exposure    2675242
# additional_information      2630456
# chronic_disease_binary            0
# chronic_disease             2676096
# source                       566964
# sequence_available          2676299
# outcome                     2368929
# date_death_or_discharge     2673163
# notes_for_discussion        2675671
# location                    2662935
# admin3                      2595877
# admin2                      1850257
# admin1                      1418753
# country_new                   30562
# admin_id                         70
# data_moderator_initials      933328
# travel_history_binary         65579
# dtype: int64

# %% [markdown]
# in the code below we have to drop many columns of 'df', because it has got lots of missing values (NaN) and some have useless information:

# %%
df2 = df.drop(columns=['ID','age','sex','city','date_onset_symptoms','date_admission_hospital','symptoms','lives_in_Wuhan','travel_history_dates',
         'travel_history_location','reported_market_exposure','additional_information','chronic_disease','source','sequence_available','outcome',
         'date_death_or_discharge','notes_for_discussion','location','admin3','admin2','admin1','country_new','data_moderator_initials'
])
df2
# Out:
#                  province    country   latitude   longitude geo_resolution  \
# 0               Hong Kong      China  22.365019  114.133808          point
# 1                  Veneto      Italy  45.297748   11.658382          point
# 2                     NaN  Singapore   1.353460  103.815100         admin0
# 3                   Henan      China  34.629310  113.468000         admin2
# 4                 Jiangxi      China  27.513560  113.902900         admin2
# ...                   ...        ...        ...         ...            ...
# 2676306  Coronel Portillo       Peru  -8.378190  -74.539700          point
# 2676307              Lima       Peru -12.076530  -77.067350          point
# 2676308              Lima       Peru -11.932980  -77.040850          point
# 2676309            Callao       Peru -12.000740  -77.118240          point
# 2676310              Lima       Peru -11.976260  -77.075030          point
#
#         date_confirmation  chronic_disease_binary  admin_id  \
# 0              14.02.2020                   False    8029.0
# 1              21.02.2020                   False    8954.0
# 2              14.02.2020                   False     200.0
# 3              26.01.2020                   False   10091.0
# 4              14.02.2020                   False    7060.0
# ...                   ...                     ...       ...
# 2676306        17.05.2020                   False   14429.0
# 2676307        17.05.2020                   False   14695.0
# 2676308        17.05.2020                   False   14400.0
# 2676309        17.05.2020                   False   14516.0
# 2676310        17.05.2020                   False   14502.0
#
#         travel_history_binary
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 2676306                 False
# 2676307                 False
# 2676308                 False
# 2676309                 False
# 2676310                 False
#
# [2676311 rows x 9 columns]

# %% [markdown]
# calculating NaN values again:

# %%
df2.isnull().sum()
# Out:
# province                  452664
# country                      115
# latitude                      70
# longitude                     70
# geo_resolution                70
# date_confirmation         108489
# chronic_disease_binary         0
# admin_id                      70
# travel_history_binary      65579
# dtype: int64

# %% [markdown]
# now we can just drop rows that contains NaN values:

# %%
df2.dropna(inplace=True)
print(f'Null values:\n{df2.isnull().sum()}')
print('='*27)
print(f'df2 shape: {df2.shape}')
# Out:
# Null values:
# province                  0
# country                   0
# latitude                  0
# longitude                 0
# geo_resolution            0
# date_confirmation         0
# chronic_disease_binary    0
# admin_id                  0
# travel_history_binary     0
# dtype: int64
# ===========================
# df2 shape: (2054896, 9)

# %%
 df2
# Out:
#                         province       country   latitude  longitude  \
# 66025              Kwazulu-Natal  South Africa -28.742200  30.721600
# 66859    Niamey Capital District         Niger  13.511667   2.125278
# 66870    Niamey Capital District         Niger  13.511667   2.125278
# 66881    Niamey Capital District         Niger  13.511667   2.125278
# 66892    Niamey Capital District         Niger  13.511667   2.125278
# ...                          ...           ...        ...        ...
# 2676306         Coronel Portillo          Peru  -8.378190 -74.539700
# 2676307                     Lima          Peru -12.076530 -77.067350
# 2676308                     Lima          Peru -11.932980 -77.040850
# 2676309                   Callao          Peru -12.000740 -77.118240
# 2676310                     Lima          Peru -11.976260 -77.075030
#
#         geo_resolution date_confirmation  chronic_disease_binary  admin_id  \
# 66025           admin1        05.03.2020                   False     539.0
# 66859           admin2        20.03.2020                   False    6560.0
# 66870           admin2        21.03.2020                   False    6560.0
# 66881           admin2        23.03.2020                   False    6560.0
# 66892           admin2        24.03.2020                   False    6560.0
# ...                ...               ...                     ...       ...
# 2676306          point        17.05.2020                   False   14429.0
# 2676307          point        17.05.2020                   False   14695.0
# 2676308          point        17.05.2020                   False   14400.0
# 2676309          point        17.05.2020                   False   14516.0
# 2676310          point        17.05.2020                   False   14502.0
#
#         travel_history_binary
# 66025                    True
# 66859                   False
# 66870                    True
# 66881                    True
# 66892                    True
# ...                       ...
# 2676306                 False
# 2676307                 False
# 2676308                 False
# 2676309                 False
# 2676310                 False
#
# [2054896 rows x 9 columns]

# %% [markdown]
# setting 'country' column to index makes table more prettier:

# %%
df3 = df2.set_index('country')
df3
# Out:
#                              province   latitude  longitude geo_resolution  \
# country
# South Africa            Kwazulu-Natal -28.742200  30.721600         admin1
# Niger         Niamey Capital District  13.511667   2.125278         admin2
# Niger         Niamey Capital District  13.511667   2.125278         admin2
# Niger         Niamey Capital District  13.511667   2.125278         admin2
# Niger         Niamey Capital District  13.511667   2.125278         admin2
# ...                               ...        ...        ...            ...
# Peru                 Coronel Portillo  -8.378190 -74.539700          point
# Peru                             Lima -12.076530 -77.067350          point
# Peru                             Lima -11.932980 -77.040850          point
# Peru                           Callao -12.000740 -77.118240          point
# Peru                             Lima -11.976260 -77.075030          point
#
#              date_confirmation  chronic_disease_binary  admin_id  \
# country
# South Africa        05.03.2020                   False     539.0
# Niger               20.03.2020                   False    6560.0
# Niger               21.03.2020                   False    6560.0
# Niger               23.03.2020                   False    6560.0
# Niger               24.03.2020                   False    6560.0
# ...                        ...                     ...       ...
# Peru                17.05.2020                   False   14429.0
# Peru                17.05.2020                   False   14695.0
# Peru                17.05.2020                   False   14400.0
# Peru                17.05.2020                   False   14516.0
# Peru                17.05.2020                   False   14502.0
#
#              travel_history_binary
# country
# South Africa                  True
# Niger                        False
# Niger                         True
# Niger                         True
# Niger                         True
# ...                            ...
# Peru                         False
# Peru                         False
# Peru                         False
# Peru                         False
# Peru                         False
#
# [2054896 rows x 8 columns]

# %% [markdown]
# grouping columns makes more easier to understand the table:

# %%
df4 = df3.groupby(['country','province']).max()
df4
# Out:
#                                  latitude   longitude geo_resolution  \
# country     province
# Afghanistan Herat               34.341944   62.203056         admin1
# Algeria     Adrar               27.866667   -0.283333         admin2
#             Ain Defla           36.265200    1.970300         admin2
#             Ain Temouchent      35.300000   -1.133333         admin2
#             Alger               36.753889    3.058889         admin2
# ...                                   ...         ...            ...
# Vietnam     Khanh Hoa           12.238800  109.196700          point
#             Thanh Hoa           19.806749  105.784921          point
#             Vinh Phuc           21.407000  105.678812          point
# Zimbabwe    Harare             -17.850000   31.050000         admin2
#             Matabeleland North -17.933333   25.833333         admin2
#
#                                date_confirmation  chronic_disease_binary  \
# country     province
# Afghanistan Herat                     24.02.2020                   False
# Algeria     Adrar                     24.03.2020                   False
#             Ain Defla                 31.03.2020                   False
#             Ain Temouchent            31.03.2020                   False
#             Alger                     31.03.2020                   False
# ...                                          ...                     ...
# Vietnam     Khanh Hoa                 31.01.2020                    True
#             Thanh Hoa                 30.01.2020                   False
#             Vinh Phuc                 30.01.2020                   False
# Zimbabwe    Harare                    27.03.2020                   False
#             Matabeleland North        20.03.2020                   False
#
#                                 admin_id  travel_history_binary
# country     province
# Afghanistan Herat                  470.0                   True
# Algeria     Adrar                  995.0                  False
#             Ain Defla             1007.0                  False
#             Ain Temouchent        1008.0                  False
#             Alger                 1051.0                  False
# ...                                  ...                    ...
# Vietnam     Khanh Hoa             6557.0                   True
#             Thanh Hoa             8581.0                   True
#             Vinh Phuc             8585.0                   True
# Zimbabwe    Harare                4003.0                   True
#             Matabeleland North    8926.0                   True
#
# [1200 rows x 7 columns]

# %% [markdown]
# and now we can show the result with vizual plot (barplot):

# %%
plt.figure(figsize=(20,12))
sns.barplot(x=df3.index, y=df3['admin_id'])

plt.title('COVID-19 Infected Person List')
plt.xlabel('Country')
plt.xticks(rotation=90)
plt.ylabel('People')
plt.grid()

# %%
df3.to_csv('task_2.csv')
